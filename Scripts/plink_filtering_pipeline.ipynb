# %%
import subprocess
import os

# === CONFIGURATION ===
vcf_input = "/mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/cohort_snps.vcf"
work_dir = "/mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis"
os.makedirs(work_dir, exist_ok=True)

plink_prefix = f"{work_dir}/cohort_plink"
stats_prefix = f"{work_dir}/cohort_stats"
filtered_prefix = f"{work_dir}/cohort_filtered"
final_vcf = f"{work_dir}/cohort_filtered_snps.vcf"

# === STEP 1: Convert VCF to PLINK format ===
subprocess.run([
    "plink", "--vcf", vcf_input,
    "--allow-extra-chr",  # Accept non-standard chromosome names
    "--make-bed", "--out", plink_prefix
], check=True)

# === STEP 2: Compute MAF and F_MISS ===
subprocess.run([
    "plink", "--bfile", plink_prefix,
    "--allow-extra-chr",  
    "--freq",
    "--missing",
    "--out", stats_prefix
], check=True)

# === STEP 3: Filter SNPs ===
subprocess.run([
    "plink", "--bfile", plink_prefix,
    "--allow-extra-chr",  
    "--maf", "0.1",
    "--geno", "0.05",
    "--make-bed",
    "--out", filtered_prefix
], check=True)

# === STEP 4: Export to VCF ===
subprocess.run([
    "plink", "--bfile", filtered_prefix,
    "--allow-extra-chr",  
    "--recode", "vcf",
    "--out", final_vcf.replace(".vcf", "")
], check=True)

print(f"✅ Done! Final VCF: {final_vcf}")
# Out:
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_plink.log.
# Options in effect:
#   --allow-extra-chr
#   --make-bed
#   --out /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_plink
#   --vcf /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/cohort_snps.vcf
#
# 39261 MB RAM detected; reserving 19630 MB for main workspace.
# --vcf: 32211k variants complete.
# /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_plink-temporary.bed
# +
# /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_plink-temporary.bim
# +
# /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_plink-temporary.fam
# written.
# 32211171 variants loaded from .bim file.
# 21 people (0 males, 0 females, 21 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_plink.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 21 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.63097.
# 32211171 variants and 21 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_plink.bed
# +
# /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_plink.bim
# +
# /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_plink.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_stats.log.
# Options in effect:
#   --allow-extra-chr
#   --bfile /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_plink
#   --freq
#   --missing
#   --out /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_stats
#
# 39261 MB RAM detected; reserving 19630 MB for main workspace.
# 32211171 variants loaded from .bim file.
# 21 people (0 males, 0 females, 21 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_stats.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 21 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.63097.
# --freq: Allele frequencies (founders only) written to
# /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_stats.frq
# .
# --missing: Sample missing data report written to
# /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_stats.imiss,
# and variant-based missing data report written to
# /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_stats.lmiss.
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_filtered.log.
# Options in effect:
#   --allow-extra-chr
#   --bfile /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_plink
#   --geno 0.05
#   --maf 0.1
#   --make-bed
#   --out /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_filtered
#
# 39261 MB RAM detected; reserving 19630 MB for main workspace.
# 32211171 variants loaded from .bim file.
# 21 people (0 males, 0 females, 21 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_filtered.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 21 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.63097.
# 30536720 variants removed due to missing genotype data (--geno).
# 1395948 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 278503 variants and 21 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_filtered.bed
# +
# /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_filtered.bim
# +
# /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_filtered.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_filtered_snps.log.
# Options in effect:
#   --allow-extra-chr
#   --bfile /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_filtered
#   --out /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_filtered_snps
#   --recode vcf
#
# 39261 MB RAM detected; reserving 19630 MB for main workspace.
# 278503 variants loaded from .bim file.
# 21 people (0 males, 0 females, 21 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_filtered_snps.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 21 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.959466.
# 278503 variants and 21 people pass filters and QC.
# Note: No phenotypes present.
# --recode vcf to
# /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_filtered_snps.vcf
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# ✅ Done! Final VCF: /mnt/jupiter/johnsonlab/Capstone_proj/results/BQSR/plink_analysis/cohort_filtered_snps.vcf
